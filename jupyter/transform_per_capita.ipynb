# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 70)

# %%
df = pd.read_csv('../csv/completa.csv')

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df_sum = df.sum(axis=0,numeric_only=True).sort_values(ascending=False)

df_sum
# Out:
# GDP                                           1.173081e+15
# Population                                    1.520576e+11
# Total                                         1.165289e+09
# Cardiovascular Diseases                       3.518111e+08
# Neoplasms                                     1.819480e+08
# Chronic Respiratory Diseases                  8.537727e+07
# Lower Respiratory Infections                  6.708974e+07
# Neonatal Disorders                            6.215797e+07
# Diarrheal Diseases                            5.517836e+07
# Digestive Diseases                            5.144702e+07
# GDP/cap                                       3.804187e+07
# Tuberculosis                                  3.746135e+07
# HIV/AIDS                                      3.067545e+07
# Cirrhosis and Other Chronic Liver Diseases    2.876172e+07
# Road Injuries                                 2.746932e+07
# Diabetes Mellitus                             2.359959e+07
# ...

# %%
df[df['Country']=='Russia']
# Out:
#      Country  Year  Obesity(%)  Unemployment  Meningitis  \
# 2983  Russia  1991        18.7          5.41        2199
# 2984  Russia  1992        19.0          5.18        2253
# 2985  Russia  1993        19.2          5.88        2564
# 2986  Russia  1994        19.4          8.13        2803
# 2987  Russia  1995        19.6          9.45        2689
# 2988  Russia  1996        19.8          9.67        2387
# 2989  Russia  1997        20.0         11.81        2203
# 2990  Russia  1998        20.2         13.26        2112
# 2991  Russia  1999        20.3         13.04        2230
# 2992  Russia  2000        20.5         10.58        2315
# 2993  Russia  2001        20.7          8.98        2362
# 2994  Russia  2002        20.9          7.88        2380
# 2995  Russia  2003        21.1          8.21        2402
# 2996  Russia  2004        21.4          7.76        2310
# 2997  Russia  2005        21.6          7.12        2337
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Obesity(%)', 'Unemployment', 'Meningitis',
#        'Alzheimers Disease and Other Dementias', 'Parkinsons Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis', 'Total', 'GDP',
#        'GDP/cap', 'Elect(lib)', 'CO2/cap', 'Total alcohol per capita(L)',
# ...

# %%
df['Alzheimers Disease and Other Dementias/cap'] = df['Alzheimers Disease and Other Dementias']/df['Population']
df['Acute Hepatitis/cap'] = df['Acute Hepatitis']/df['Population']
df['Digestive Diseases/cap'] = df['Digestive Diseases']/df['Population']
df['Cirrhosis and Other Chronic Liver Diseases/cap'] = df['Cirrhosis and Other Chronic Liver Diseases']/df['Population']
df['Poisonings/cap'] = df['Poisonings']/df['Population']
df['Road Injuries/cap'] = df['Road Injuries']/df['Population']
df['Conflict and Terrorism/cap'] = df['Conflict and Terrorism']/df['Population']
df['Environmental Heat and Cold Exposure/cap'] = df['Environmental Heat and Cold Exposure']/df['Population']
df['Alcohol Use Disorders/cap'] = df['Alcohol Use Disorders']/df['Population']
df['HIV/AIDS/cap'] = df['HIV/AIDS']/df['Population']
df['Nutritional Deficiencies/cap'] = df['Nutritional Deficiencies']/df['Population']
df['Interpersonal Violence/cap'] = df['Interpersonal Violence']/df['Population']
df['Neoplasms/cap'] = df['Neoplasms']/df['Population']
df['Neonatal Disorders/cap'] = df['Neonatal Disorders']/df['Population']
df['Respiratory Diseases/cap'] = (df['Lower Respiratory Infections']+df['Chronic Respiratory Diseases'])/df['Population']
df['Tuberculosis/cap'] = df['Tuberculosis']/df['Population']
df['Self-harm/cap'] = df['Self-harm']/df['Population']
df['Diabetes Mellitus/cap'] = df['Diabetes Mellitus']/df['Population']
df['Alzheimers Disease and Other Dementias/cap'] = df['Alzheimers Disease and Other Dementias']/df['Population']
df['Cardiovascular Diseases/cap'] = df['Cardiovascular Diseases']/df['Population']
df['Chronic Respiratory Diseases/cap'] = df['Chronic Respiratory Diseases']/df['Population']
df['Drug Use Disorders/cap'] = df['Drug Use Disorders']/df['Population']

# %%
df.sum(axis=0,numeric_only=True).sort_values(ascending=False)
# Out:
# GDP                                               1.173081e+15
# Population                                        1.520576e+11
# Total                                             1.165289e+09
# Cardiovascular Diseases                           3.518111e+08
# Neoplasms                                         1.819480e+08
# Chronic Respiratory Diseases                      8.537727e+07
# Lower Respiratory Infections                      6.708974e+07
# Neonatal Disorders                                6.215797e+07
# Diarrheal Diseases                                5.517836e+07
# Digestive Diseases                                5.144702e+07
# GDP/cap                                           3.804187e+07
# Tuberculosis                                      3.746135e+07
# HIV/AIDS                                          3.067545e+07
# Cirrhosis and Other Chronic Liver Diseases        2.876172e+07
# Road Injuries                                     2.746932e+07
# ...

# %%
df.head(60)
# Out:
#         Country  Year  Obesity(%)  Unemployment  Meningitis  \
# 0   Afghanistan  1991         1.1         10.65        2218
# 1   Afghanistan  1992         1.2         10.82        2475
# 2   Afghanistan  1993         1.2         10.72        2812
# 3   Afghanistan  1994         1.3         10.73        3027
# 4   Afghanistan  1995         1.4         11.18        3102
# 5   Afghanistan  1996         1.5         10.96        3193
# 6   Afghanistan  1997         1.6         10.78        3304
# 7   Afghanistan  1998         1.7         10.80        3281
# 8   Afghanistan  1999         1.8         10.81        3200
# 9   Afghanistan  2000         1.9         10.81        3105
# 10  Afghanistan  2001         2.0         10.81        3063
# 11  Afghanistan  2002         2.1         11.26        2990
# 12  Afghanistan  2003         2.2         11.14        3300
# 13  Afghanistan  2004         2.3         10.99        3350
# 14  Afghanistan  2005         2.5         11.22        3238
# ...

# %%
df.isna().sum()
# Out:
# Country                                              0
# Year                                                 0
# Obesity(%)                                           0
# Unemployment                                         0
# Meningitis                                           0
# Alzheimers Disease and Other Dementias               0
# Parkinsons Disease                                   0
# Nutritional Deficiencies                             0
# Malaria                                              0
# Drowning                                             0
# Interpersonal Violence                               0
# Maternal Disorders                                   0
# HIV/AIDS                                             0
# Drug Use Disorders                                   0
# Tuberculosis                                         0
# Cardiovascular Diseases                              0
# Lower Respiratory Infections                         0
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Obesity(%)', 'Unemployment', 'Meningitis',
#        'Alzheimers Disease and Other Dementias', 'Parkinsons Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis', 'Total', 'GDP',
#        'GDP/cap', 'Elect(lib)', 'CO2/cap', 'Population',
# ...

# %%
df.columns = df.columns.str.replace('/', ' ')

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Obesity(%)', 'Unemployment', 'Meningitis',
#        'Alzheimers Disease and Other Dementias', 'Parkinsons Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis', 'Total', 'GDP',
#        'GDP cap', 'Elect(lib)', 'CO2 cap', 'Population',
# ...

# %%
mapeo_nombres = {'Elect(lib)': 'lib lvl','Fire, Heat, and Hot Substances': 'Fire', 'HIV/AIDS': 'AIDS','Obesity(%)': 'Obesity'}


df = df.rename(columns=mapeo_nombres)

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Obesity', 'Unemployment', 'Meningitis',
#        'Alzheimers_Disease_and_Other_Dementias', 'Parkinsons_Disease',
#        'Nutritional_Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal_Violence', 'Maternal_Disorders', 'HIV_AIDS',
#        'Drug_Use_Disorders', 'Tuberculosis', 'Cardiovascular_Diseases',
#        'Lower_Respiratory_Infections', 'Neonatal_Disorders',
#        'Alcohol_Use_Disorders', 'Self-harm', 'Exposure_to_Forces_of_Nature',
#        'Diarrheal_Diseases', 'Environmental_Heat_and_Cold_Exposure',
#        'Neoplasms', 'Conflict_and_Terrorism', 'Diabetes_Mellitus',
#        'Chronic_Kidney_Disease', 'Poisonings', 'Protein-Energy_Malnutrition',
#        'Road_Injuries', 'Chronic_Respiratory_Diseases',
#        'Cirrhosis_and_Other_Chronic_Liver_Diseases', 'Digestive_Diseases',
#        'Fire', 'Acute_Hepatitis', 'Total', 'GDP', 'GDP_cap', 'lib_lvl',
#        'CO2_cap', 'Population', 'Alzheimers_Disease_and_Other_Dementias_cap',
# ...

# %%
df = df.drop('Total alcohol per capita(L)', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df = df.drop('Total alcohol per capita(L)', axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df['Respiratory Diseases'] = df['Lower_Respiratory_Infections'] + df['Chronic_Respiratory_Diseases']

df
# Out:
#           Country  Year  Obesity  Unemployment  Meningitis  \
# 0     Afghanistan  1991      1.1         10.65        2218
# 1     Afghanistan  1992      1.2         10.82        2475
# 2     Afghanistan  1993      1.2         10.72        2812
# 3     Afghanistan  1994      1.3         10.73        3027
# 4     Afghanistan  1995      1.4         11.18        3102
# ...           ...   ...      ...           ...         ...
# 3888     Zimbabwe  2012     11.1          5.15        1586
# 3889     Zimbabwe  2013     11.3          4.98        1448
# 3890     Zimbabwe  2014     11.6          4.77        1422
# 3891     Zimbabwe  2015     11.9          4.78        1439
# 3892     Zimbabwe  2016     12.3          4.79        1457
#
#       Alzheimers_Disease_and_Other_Dementias  Parkinsons_Disease  \
# 0                                       1136                 374
# 1                                       1162                 378
# ...

# %%
df['mortality'] = df['Total'] / df['Population']
df
# Out:
#           Country  Year  Obesity  Unemployment  Meningitis  \
# 0     Afghanistan  1991      1.1         10.65        2218
# 1     Afghanistan  1992      1.2         10.82        2475
# 2     Afghanistan  1993      1.2         10.72        2812
# 3     Afghanistan  1994      1.3         10.73        3027
# 4     Afghanistan  1995      1.4         11.18        3102
# ...           ...   ...      ...           ...         ...
# 3888     Zimbabwe  2012     11.1          5.15        1586
# 3889     Zimbabwe  2013     11.3          4.98        1448
# 3890     Zimbabwe  2014     11.6          4.77        1422
# 3891     Zimbabwe  2015     11.9          4.78        1439
# 3892     Zimbabwe  2016     12.3          4.79        1457
#
#       Alzheimers_Disease_and_Other_Dementias  Parkinsons_Disease  \
# 0                                       1136                 374
# 1                                       1162                 378
# ...

# %%
df_health = pd.read_excel('../csv/healthcare_data.XLSX')

# %%
df_health
# Out:
#        country code region        income  year   che_gdp  che_pc_usd  \
# 0      Algeria  DZA    AFR  Lower-middle  2000  3.489033   62.117695
# 1      Algeria  DZA    AFR  Lower-middle  2001  3.837877   67.338501
# 2      Algeria  DZA    AFR  Lower-middle  2002  3.730042   66.947601
# 3      Algeria  DZA    AFR  Lower-middle  2003  3.601041   76.235474
# 4      Algeria  DZA    AFR  Lower-middle  2004  3.544073   93.024330
# ...        ...  ...    ...           ...   ...       ...         ...
# 4238  Viet Nam  VNM    WPR  Lower-middle  2017  4.990148  149.308792
# 4239  Viet Nam  VNM    WPR  Lower-middle  2018  5.026788  164.236496
# 4240  Viet Nam  VNM    WPR  Lower-middle  2019  4.974075  173.649490
# 4241  Viet Nam  VNM    WPR  Lower-middle  2020  4.300619  154.235107
# 4242  Viet Nam  VNM    WPR  Lower-middle  2021  4.593464  172.552979
#
#         hk_gdp  hk_g_gdp  hk_ext_gdp           che         gghed  \
# 0          NaN       NaN         NaN  1.438703e+05  1.035340e+05
# ...

# %%
df_health = df_health[['country', 'year', 'che_gdp', 'che']]

# %%
df_health = df_health.rename(columns={'country': 'Country', 'year': 'Year', 'che_gdp': 'che gdp'})

# %%
df_health
# Out:
#        Country  Year   che gdp           che
# 0      Algeria  2000  3.489033  1.438703e+05
# 1      Algeria  2001  3.837877  1.622309e+05
# 2      Algeria  2002  3.730042  1.687023e+05
# 3      Algeria  2003  3.601041  1.891375e+05
# 4      Algeria  2004  3.544073  2.179286e+05
# ...        ...   ...       ...           ...
# 4238  Viet Nam  2017  4.990148  3.140751e+08
# 4239  Viet Nam  2018  5.026788  3.523297e+08
# 4240  Viet Nam  2019  4.974075  3.833619e+08
# 4241  Viet Nam  2020  4.300619  3.459583e+08
# 4242  Viet Nam  2021  4.593464  3.895105e+08
#
# [4243 rows x 4 columns]

# %%
merged_df = pd.merge(df, df_health, on=['Country', 'Year'], how='outer')

merged_df
# Out:
#           Country  Year  Obesity  Unemployment  Meningitis  \
# 0     Afghanistan  1991      1.1         10.65      2218.0
# 1     Afghanistan  1992      1.2         10.82      2475.0
# 2     Afghanistan  1993      1.2         10.72      2812.0
# 3     Afghanistan  1994      1.3         10.73      3027.0
# 4     Afghanistan  1995      1.4         11.18      3102.0
# ...           ...   ...      ...           ...         ...
# 5717     Viet Nam  2017      NaN           NaN         NaN
# 5718     Viet Nam  2018      NaN           NaN         NaN
# 5719     Viet Nam  2019      NaN           NaN         NaN
# 5720     Viet Nam  2020      NaN           NaN         NaN
# 5721     Viet Nam  2021      NaN           NaN         NaN
#
#       Alzheimers_Disease_and_Other_Dementias  Parkinsons_Disease  \
# 0                                     1136.0               374.0
# 1                                     1162.0               378.0
# ...

# %%
df_filtrado = merged_df.dropna(thresh=len(merged_df.columns) - 5)
df_filtrado
# Out:
#           Country  Year  Obesity  Unemployment  Meningitis  \
# 0     Afghanistan  1991      1.1         10.65      2218.0
# 1     Afghanistan  1992      1.2         10.82      2475.0
# 2     Afghanistan  1993      1.2         10.72      2812.0
# 3     Afghanistan  1994      1.3         10.73      3027.0
# 4     Afghanistan  1995      1.4         11.18      3102.0
# ...           ...   ...      ...           ...         ...
# 3888     Zimbabwe  2012     11.1          5.15      1586.0
# 3889     Zimbabwe  2013     11.3          4.98      1448.0
# 3890     Zimbabwe  2014     11.6          4.77      1422.0
# 3891     Zimbabwe  2015     11.9          4.78      1439.0
# 3892     Zimbabwe  2016     12.3          4.79      1457.0
#
#       Alzheimers_Disease_and_Other_Dementias  Parkinsons_Disease  \
# 0                                     1136.0               374.0
# 1                                     1162.0               378.0
# ...

# %%
df = df_filtrado

# %%
df_alc = pd.read_csv('../csv/total-alcohol-consumption-per-capita-litres-of-pure- ahcool new.csv')
# Out:
#           Entity Code  Year  \
# 0    Afghanistan  AFG  2010
# 1    Afghanistan  AFG  2015
# 2    Afghanistan  AFG  2018
# 3        Albania  ALB  2000
# 4        Albania  ALB  2005
# ..           ...  ...   ...
# 989     Zimbabwe  ZWE  2000
# 990     Zimbabwe  ZWE  2005
# 991     Zimbabwe  ZWE  2010
# 992     Zimbabwe  ZWE  2015
# 993     Zimbabwe  ZWE  2018
#
#     Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)
# 0                                                 0.21
# 1                                                 0.21
# 2                                                 0.21
# 3                                                 6.57
# 4                                                 7.65
# ..                                                 ...
# 989                                               2.46
# 990                                               2.77
# 991                                               3.93
# ...

# %%
df_alc = df_alc.rename(columns={'Entity': 'Country', 'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)': 'Alcohol consum'})

df_alc = df_alc[['Country', 'Year', 'Alcohol consum']]

df_alc
# Out:
#          Country  Year Alcohol consum
# 0    Afghanistan  2010           0.21
# 1    Afghanistan  2015           0.21
# 2    Afghanistan  2018           0.21
# 3        Albania  2000           6.57
# 4        Albania  2005           7.65
# ..           ...   ...            ...
# 989     Zimbabwe  2000           2.46
# 990     Zimbabwe  2005           2.77
# 991     Zimbabwe  2010           3.93
# 992     Zimbabwe  2015           4.92
# 993     Zimbabwe  2018           4.67
#
# [994 rows x 3 columns]

# %%
df_merg = pd.merge(df, df_alc, on=['Country', 'Year'], how='outer')

df_merg
# Out:
#           Country  Year  Obesity  Unemployment  Meningitis  \
# 0     Afghanistan  1991      1.1         10.65      2218.0
# 1     Afghanistan  1992      1.2         10.82      2475.0
# 2     Afghanistan  1993      1.2         10.72      2812.0
# 3     Afghanistan  1994      1.3         10.73      3027.0
# 4     Afghanistan  1995      1.4         11.18      3102.0
# ...           ...   ...      ...           ...         ...
# 4293        Yemen  2010      NaN           NaN         NaN
# 4294        Yemen  2015      NaN           NaN         NaN
# 4295        Yemen  2018      NaN           NaN         NaN
# 4296       Zambia  2018      NaN           NaN         NaN
# 4297     Zimbabwe  2018      NaN           NaN         NaN
#
#       Alzheimers_Disease_and_Other_Dementias  Parkinsons_Disease  \
# 0                                     1136.0               374.0
# 1                                     1162.0               378.0
# ...

# %%
df_3 = df_merg.dropna(thresh=len(df_merg.columns) - 5)

df_3
# Out:
#           Country  Year  Obesity  Unemployment  Meningitis  \
# 0     Afghanistan  1991      1.1         10.65      2218.0
# 1     Afghanistan  1992      1.2         10.82      2475.0
# 2     Afghanistan  1993      1.2         10.72      2812.0
# 3     Afghanistan  1994      1.3         10.73      3027.0
# 4     Afghanistan  1995      1.4         11.18      3102.0
# ...           ...   ...      ...           ...         ...
# 3888     Zimbabwe  2012     11.1          5.15      1586.0
# 3889     Zimbabwe  2013     11.3          4.98      1448.0
# 3890     Zimbabwe  2014     11.6          4.77      1422.0
# 3891     Zimbabwe  2015     11.9          4.78      1439.0
# 3892     Zimbabwe  2016     12.3          4.79      1457.0
#
#       Alzheimers_Disease_and_Other_Dementias  Parkinsons_Disease  \
# 0                                     1136.0               374.0
# 1                                     1162.0               378.0
# ...

# %%
df['Alcohol consum'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 3893 entries, 0 to 3892
# Series name: Alcohol consum
# Non-Null Count  Dtype
# --------------  -----
# 589 non-null    object
# dtypes: object(1)
# memory usage: 60.8+ KB

# %%
df['Alcohol consum'] = df['Alcohol consum'].astype(float)

df
# Out:
# C:\Users\Gonzalo\AppData\Local\Temp\ipykernel_19500\3088736304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Alcohol consum'] = df['Alcohol consum'].astype(float)
#           Country  Year  Obesity  Unemployment  Meningitis  \
# 0     Afghanistan  1991      1.1         10.65      2218.0
# 1     Afghanistan  1992      1.2         10.82      2475.0
# 2     Afghanistan  1993      1.2         10.72      2812.0
# 3     Afghanistan  1994      1.3         10.73      3027.0
# 4     Afghanistan  1995      1.4         11.18      3102.0
# ...           ...   ...      ...           ...         ...
# 3888     Zimbabwe  2012     11.1          5.15      1586.0
# 3889     Zimbabwe  2013     11.3          4.98      1448.0
# ...

# %%
df['che gdp'].max()
# Out:
# 19.690046309999996

# %%
df['che %'] = df['GDP'] * df['che gdp'] / 100
# Out:
# C:\Users\Gonzalo\AppData\Local\Temp\ipykernel_19500\2543303860.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['che %'] = df['GDP'] * df['che gdp'] / 100

# %%
df['Alcohol consum'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 3893 entries, 0 to 3892
# Series name: Alcohol consum
# Non-Null Count  Dtype
# --------------  -----
# 589 non-null    float64
# dtypes: float64(1)
# memory usage: 60.8 KB

# %%
df = df_3

# %%
df.isna().sum()
# Out:
# Country                                              0
# Year                                                 0
# Obesity                                              0
# Unemployment                                         0
# Meningitis                                           0
# Alzheimers_Disease_and_Other_Dementias               0
# Parkinsons_Disease                                   0
# Nutritional_Deficiencies                             0
# Malaria                                              0
# Drowning                                             0
# Interpersonal_Violence                               0
# Maternal_Disorders                                   0
# HIV_AIDS                                             0
# Drug_Use_Disorders                                   0
# Tuberculosis                                         0
# Cardiovascular_Diseases                              0
# Lower_Respiratory_Infections                         0
# ...

# %%
df['Neoplasms_cap'].mean()
# Out:
# 0.0012034838440313593

# %%
df.to_csv('../csv/completa_per_cap.csv', index=False)

# %%
df.to_csv('../csv/completaindex.csv')

# %%
df.to_excel('../csv/prueba.xlsx')
